# %%
import sys
import os

# Add the src/ directory to sys.path
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..', 'src')))
#print(sys.path)

import cold.models.autogenerated as cold

from pydantic import ValidationError
import json

# %%
charging_1=cold.ConstantCurrentCharging()
chargingcrate_1=cold.ChargingCRate(1/3,"UnitOne")
capacity_1=cold.Capacity()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 charging_1=cold.ConstantCurrentCharging()
#       2 chargingcrate_1=cold.ChargingCRate(1/3,"UnitOne")
# ----> 3 capacity_1=cold.Capacity()
#
# File c:\Users\sridevik\SINTEF\projects\digibatt\cold_2\cold\src\cold\models\autogenerated\__init__.py:4109, in __getattr__(name)
#    4107 def __getattr__(name):
#    4108     if name in __all__:
# -> 4109         module = importlib.import_module(f".{name}Module", package=__name__)
#    4110         return getattr(module, name)
#    4111     raise AttributeError(f"module {__name__} has no attribute {name}")
#
# File c:\Users\sridevik\AppData\Local\anaconda3\envs\Demo-Linked-data\lib\importlib\__init__.py:127, in import_module(name, package)
#     125             break
#     126         level += 1
# ...
